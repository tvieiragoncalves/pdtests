# %%
import pandas as pd

# %%
import os

# %%
a = pd.read_csv('http://centraldedados.pt/incendios2015.csv')

# %%
a.head()
# Out:
#     ano codigo_sgif    codigo_anpc          tipo          distrito  \
# 0  2015    DM315252  2015160007544     Florestal  Viana do Castelo
# 1  2015    DM215305  2015130043758     Florestal             Porto
# 2  2015    DM415293  2015030021973     Florestal             Braga
# 3  2015    DM315261  2015160007563  Falso Alarme  Viana do Castelo
# 4  2015    BL115321  2015180015874      Agrícola             Viseu
#
#              concelho           freguesia                            local  \
# 0       Ponte de Lima           Serdedelo      VALE DE TROVELA (SERDEDELO)
# 1  Marco de Canaveses  Vila Boa de Quires                    LUGAR DO FOFO
# 2          Vila Verde                Lage            RUA PROF ABEL MADEIRA
# 3       Ponte de Lima            Boalhosa  J. DEPOSITOS DE AGUA (BOALHOSA)
# 4        Castro Daire        Castro Daire      Farejinhas - Bº das Queirós
#
#       ine       x  ...  falso_alarme fogacho incendio agricola perimetro  aps  \
# ...

# %%
a.tail(5)
# Out:
#         ano codigo_sgif    codigo_anpc          tipo distrito  \
# 23170  2015   DM4151671  2015030056919     Florestal    Braga
# 23171  2015   BL1151018  2015180041997     Florestal    Viseu
# 23172  2015   BL3151227  2015010055691  Falso Alarme   Aveiro
# 23173  2015   DM2153226  2015130115988     Florestal    Porto
# 23174  2015   BL3151229  2015010055723  Falso Alarme   Aveiro
#
#                    concelho          freguesia                   local  \
# 23170                  Fafe               Fafe          RUA DE FORNELO
# 23171               Cinfães            Cinfães               Ventuzela
# 23172  Santa Maria da Feira              Feira     avenida 25 de abril
# 23173     Paços de Ferreira  Paços de Ferreira  Lugar alto das Cavadas
# 23174  Santa Maria da Feira           Rio Meão         Casais de Baixo
#
#           ine       x  ...  falso_alarme fogacho incendio agricola perimetro  \
# 23170   30709  196478  ...             0       1        0        0       NaN
# ...

# %%
a.describe(include="all")
# Out:
#             ano codigo_sgif   codigo_anpc       tipo distrito  concelho  \
# count   23175.0       23175  2.317500e+04      23175    23175     23175
# unique      NaN       23175           NaN          4       19       319
# top         NaN    BL315989           NaN  Florestal    Porto  Penafiel
# freq        NaN           1           NaN      15464     4444       477
# mean     2015.0         NaN  2.015105e+12        NaN      NaN       NaN
# std         0.0         NaN  5.314577e+07        NaN      NaN       NaN
# min      2015.0         NaN  2.015010e+12        NaN      NaN       NaN
# 25%      2015.0         NaN  2.015060e+12        NaN      NaN       NaN
# 50%      2015.0         NaN  2.015120e+12        NaN      NaN       NaN
# 75%      2015.0         NaN  2.015140e+12        NaN      NaN       NaN
# max      2015.0         NaN  2.015180e+12        NaN      NaN       NaN
#
#        freguesia   local            ine              x  ...  falso_alarme  \
# ...

# %%
a.dtypes
# Out:
# ano                            int64
# codigo_sgif                   object
# codigo_anpc                    int64
# tipo                          object
# distrito                      object
# concelho                      object
# freguesia                     object
# local                         object
# ine                            int64
# x                              int64
# y                              int64
# lat                           object
# lon                           object
# data_alerta                   object
# hora_alerta                   object
# data_extincao                 object
# hora_extincao                 object
# data_primeira_intervencao     object
# hora_primeira_intervencao     object
# fonte_alerta                 float64
# nut                           object
# area_povoamento              float64
# area_mato                    float64
# area_agricola                float64
# area_pov_mato                float64
# ...

# %%
a['concelho'].describe(include="all")
# Out:
# count        23175
# unique         319
# top       Penafiel
# freq           477
# Name: concelho, dtype: object

# %%
a['incendio'].describe()
# Out:
# count    23175.000000
# mean         0.143430
# std          0.350519
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: incendio, dtype: float64

# %%
i = a['incendio']
i.sum()
# Out:
# 3324

# %% [markdown]
# # Em 2015 houve 3324 incêndios em Portugal
